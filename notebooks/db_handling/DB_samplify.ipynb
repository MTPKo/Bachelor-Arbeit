# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import text

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:4750@localhost:5432/ba1')

# %%
df_temp = pd.read_sql_query(sqlalchemy.text('SELECT * FROM (SELECT *, row_number() over() rn FROM ke_stage.bachelor_mp_raw_ke) rnum WHERE rnum.rn % 1000 = 0 LIMIT 10000;'),engine)

# %%
df_temp.to_csv("G:/data/df_temp.csv", sep="|")

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:4750@localhost:5432/test_corpus')

# %%
try:
    df_temp.head()
    df_temp.columns = [c.lower() for c in df_temp.columns]
    df_temp.to_sql("test_corpus", engine,schema="ke_stage")
    
    print("Dataframe exisitert im Speicher & wurde in die DB geladen")
except Exception:
    print("lade Zwischengespeichertes CSV")
    df = pd.read_csv('G:/data/df_temp.csv',delimiter="|")
    df.columns = [c.lower() for c in df.columns]
    df.to_sql("test_corpus", engine,schema="ke_stage")
# Out:
# Dataframe exisitert im Speicher & wurde in die DB geladen

# %%
df_temp
# Out:
#                                              DBRECORDID  \
# 0     BASE::ftdoajarticles:oai:doaj.org/article:132b...
# 1     BASE::ftdoajarticles:oai:doaj.org/article:1339...
# 2     BASE::ftdoajarticles:oai:doaj.org/article:1345...
# 3     BASE::ftdoajarticles:oai:doaj.org/article:1352...
# 4     BASE::ftdoajarticles:oai:doaj.org/article:1361...
# ...                                                 ...
# 9995                                          M12115855
# 9996                                       MRI094225532
# 9997                                          M12117664
# 9998                                          M12118570
# 9999                                           M1212349
#
#                                  DOI            DOCTYPE ARTICLELANGAGE  \
# 0                                 []  [ARTIKEL, ONLINE]             []
# 1                                 []  [ARTIKEL, ONLINE]             []
# 2                                 []  [ARTIKEL, ONLINE]             []
# ...
